# %% [markdown]
# # Rasa Chatbot Implementation
# This notebook demonstrates the creation of a simple chatbot using Rasa.

# %% [markdown]
# Run this to install the Rasa library. I use Rasa for:
# 1. Building the chatbot.
# 2. Natural Language Processing (NLP) capabilities.
# 3. Dialogue management and handling user intents.

# %%
# !pip install rasa
# Out:
# Collecting rasa
#   Downloading rasa-3.6.4-py3-none-any.whl (836 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 836.5/836.5 kB 7.5 MB/s eta 0:00:00
# Collecting CacheControl<0.13.0,>=0.12.9 (from rasa)
#   Downloading CacheControl-0.12.14-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: PyJWT[crypto]<3.0.0,>=2.0.0 in /usr/lib/python3/dist-packages (from rasa) (2.3.0)
# Collecting SQLAlchemy<1.5.0,>=1.4.0 (from rasa)
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py<1.5,>=0.9 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.4.0)
# Collecting aio-pika<8.2.4,>=6.7.1 (from rasa)
#   Downloading aio_pika-8.2.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 5.2 MB/s eta 0:00:00
# Collecting aiogram<2.26 (from rasa)
#   Downloading aiogram-2.25.1-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=3.7.4.post0,<3.9,>=3.6 in /usr/local/lib/python3.10/dist-packages (from rasa) (3.8.5)
# Collecting apscheduler<3.10,>=3.6 (from rasa)
#   Downloading APScheduler-3.9.1.post1-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.9 MB/s eta 0:00:00
# Collecting attrs<22.2,>=19.3 (from rasa)
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.8 MB/s eta 0:00:00
# Collecting boto3<2.0.0,>=1.26.136 (from rasa)
#   Downloading boto3-1.28.25-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<2.3,>=1.2 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.2.1)
# Collecting colorclass<2.3,>=2.2 (from rasa)
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Collecting coloredlogs<16,>=10 (from rasa)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.0 MB/s eta 0:00:00
# Collecting colorhash<1.3.0,>=1.0.2 (from rasa)
#   Downloading colorhash-1.2.1-py3-none-any.whl (5.7 kB)
# Collecting confluent-kafka<3.0.0,>=1.9.2 (from rasa)
#   Downloading confluent_kafka-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 28.4 MB/s eta 0:00:00
# Collecting dask==2022.10.2 (from rasa)
#   Downloading dask-2022.10.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.6 MB/s eta 0:00:00
# Collecting fbmessenger<6.1.0,>=6.0.0 (from rasa)
#   Downloading fbmessenger-6.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: google-auth<3 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.17.3)
# Collecting joblib<1.3.0,>=0.15.1 (from rasa)
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonpickle<3.1,>=1.3 in /usr/local/lib/python3.10/dist-packages (from rasa) (3.0.1)
# Collecting jsonschema<4.18,>=3.2 (from rasa)
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 9.7 MB/s eta 0:00:00
# Collecting matplotlib<3.6,>=3.1 (from rasa)
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 62.5 MB/s eta 0:00:00
# Collecting mattermostwrapper<2.3,>=2.2 (from rasa)
#   Downloading mattermostwrapper-2.2.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting networkx<2.7,>=2.4 (from rasa)
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 60.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.19.2 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.23.5)
# Collecting packaging<21.0,>=20.0 (from rasa)
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.2.0)
# Collecting portalocker<3.0.0,>=2.7.0 (from rasa)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting prompt-toolkit<3.0.29,>=3.0 (from rasa)
#   Downloading prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 kB 23.6 MB/s eta 0:00:00
# Collecting protobuf<4.23.4,>=4.23.3 (from rasa)
#   Downloading protobuf-4.23.3-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 21.1 MB/s eta 0:00:00
# Collecting psycopg2-binary<2.10.0,>=2.8.2 (from rasa)
#   Downloading psycopg2_binary-2.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 65.7 MB/s eta 0:00:00
# Collecting pydantic<1.10.10 (from rasa)
#   Downloading pydantic-1.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: pydot<1.5,>=1.4 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.4.2)
# Collecting pykwalify<1.9,>=1.7 (from rasa)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Collecting pymongo[srv,tls]<4.4,>=3.8 (from rasa)
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.8.2)
# Collecting python-engineio!=5.0.0,<6,>=4 (from rasa)
#   Downloading python_engineio-4.5.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 6.0 MB/s eta 0:00:00
# Collecting python-socketio<6,>=4.4 (from rasa)
#   Downloading python_socketio-5.8.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.9 MB/s eta 0:00:00
# Collecting pytz<2023.0,>=2019.1 (from rasa)
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (6.0.1)
# Collecting questionary<1.11.0,>=1.5.1 (from rasa)
#   Downloading questionary-1.10.0-py3-none-any.whl (31 kB)
# Collecting randomname<0.2.0,>=0.1.5 (from rasa)
#   Downloading randomname-0.1.5.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rasa-sdk<3.7.0,>=3.6.1 (from rasa)
#   Downloading rasa_sdk-3.6.1-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 5.0 MB/s eta 0:00:00
# Collecting redis<5.0,>=4.5.3 (from rasa)
#   Downloading redis-4.6.0-py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.1/241.1 kB 14.3 MB/s eta 0:00:00
# Collecting regex<2022.11,>=2020.6 (from rasa)
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 47.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.31.0)
# Collecting rocketchat_API<1.31.0,>=0.6.31 (from rasa)
#   Downloading rocketchat_API-1.30.0-py3-none-any.whl (21 kB)
# Collecting ruamel.yaml<0.17.22,>=0.16.5 (from rasa)
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 11.0 MB/s eta 0:00:00
# Collecting sanic<21.13,>=21.12 (from rasa)
#   Downloading sanic-21.12.2-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 15.0 MB/s eta 0:00:00
# Collecting sanic-cors<2.1.0,>=2.0.0 (from rasa)
#   Downloading Sanic_Cors-2.0.1-py2.py3-none-any.whl (17 kB)
# Collecting sanic-jwt<2.0.0,>=1.6.0 (from rasa)
#   Downloading sanic_jwt-1.8.0-py3-none-any.whl (23 kB)
# Collecting sanic-routing<0.8.0,>=0.7.2 (from rasa)
#   Downloading sanic_routing-0.7.2-py3-none-any.whl (23 kB)
# Collecting scikit-learn<1.2,>=0.22 (from rasa)
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 29.6 MB/s eta 0:00:00
# Collecting scipy<1.9.0,>=1.4.1 (from rasa)
#   Downloading scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 11.4 MB/s eta 0:00:00
# Collecting sentry-sdk<1.15.0,>=0.17.0 (from rasa)
#   Downloading sentry_sdk-1.14.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (67.7.2)
# Collecting sklearn-crfsuite<0.4,>=0.3 (from rasa)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Collecting slack-sdk<4.0.0,>=3.19.2 (from rasa)
#   Downloading slack_sdk-3.21.3-py2.py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.5/276.5 kB 19.8 MB/s eta 0:00:00
# Collecting structlog<24.0.0,>=23.1.0 (from rasa)
#   Downloading structlog-23.1.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.1 MB/s eta 0:00:00
# Collecting structlog-sentry<3.0.0,>=2.0.2 (from rasa)
#   Downloading structlog_sentry-2.0.3-py3-none-any.whl (10 kB)
# Collecting tarsafe<0.0.5,>=0.0.3 (from rasa)
#   Downloading tarsafe-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.12.0)
# Collecting tensorflow-io-gcs-filesystem==0.32 (from rasa)
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 61.6 MB/s eta 0:00:00
# Collecting tensorflow-text==2.12.0 (from rasa)
#   Downloading tensorflow_text-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 66.5 MB/s eta 0:00:00
# Collecting tensorflow_hub<0.14.0,>=0.13.0 (from rasa)
#   Downloading tensorflow_hub-0.13.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 11.2 MB/s eta 0:00:00
# Collecting terminaltables<3.2.0,>=3.1.0 (from rasa)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm<5.0,>=4.31 in /usr/local/lib/python3.10/dist-packages (from rasa) (4.66.0)
# Collecting twilio<8.3,>=6.26 (from rasa)
#   Downloading twilio-8.2.2-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from rasa) (4.7.1)
# Collecting typing-utils<0.2.0,>=0.1.0 (from rasa)
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting ujson<6.0,>=1.35 (from rasa)
#   Downloading ujson-5.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 6.4 MB/s eta 0:00:00
# Collecting webexteamssdk<1.7.0,>=1.1.1 (from rasa)
#   Downloading webexteamssdk-1.6.1-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 10.0 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from rasa)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (8.1.6)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (2023.6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (1.4.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (0.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.56.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (0.4.14)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.14.1)
# Collecting aiormq~=6.4.0 (from aio-pika<8.2.4,>=6.7.1->rasa)
#   Downloading aiormq-6.4.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: yarl in /usr/local/lib/python3.10/dist-packages (from aio-pika<8.2.4,>=6.7.1->rasa) (1.9.2)
# Collecting Babel<2.10.0,>=2.9.1 (from aiogram<2.26->rasa)
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 95.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from aiogram<2.26->rasa) (2023.7.22)
# Collecting magic-filter>=1.0.9 (from aiogram<2.26->rasa)
#   Downloading magic_filter-1.0.11-py3-none-any.whl (11 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (1.3.1)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apscheduler<3.10,>=3.6->rasa) (5.0.1)
# Collecting botocore<1.32.0,>=1.31.25 (from boto3<2.0.0,>=1.26.136->rasa)
#   Downloading botocore-1.31.25-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 77.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.26.136->rasa)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3<2.0.0,>=1.26.136->rasa)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from CacheControl<0.13.0,>=0.12.9->rasa) (1.0.5)
# Collecting humanfriendly>=9.1 (from coloredlogs<16,>=10->rasa)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa) (4.9)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema<4.18,>=3.2->rasa)
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (3.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.0.29,>=3.0->rasa) (0.2.6)
# Requirement already satisfied: cryptography>=3.3.1 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (41.0.3)
# Collecting docopt>=0.6.2 (from pykwalify<1.9,>=1.7->rasa)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv,tls]<4.4,>=3.8->rasa)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 30.0 MB/s eta 0:00:00
# Collecting bidict>=0.21.0 (from python-socketio<6,>=4.4->rasa)
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting fire (from randomname<0.2.0,>=0.1.5->rasa)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa) (2.0.4)
# Collecting ruamel.yaml.clib>=0.2.6 (from ruamel.yaml<0.17.22,>=0.16.5->rasa)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 37.0 MB/s eta 0:00:00
# Collecting httptools>=0.0.10 (from sanic<21.13,>=21.12->rasa)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 26.3 MB/s eta 0:00:00
# Collecting aiofiles>=0.6.0 (from sanic<21.13,>=21.12->rasa)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa)
#   Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 18.4 MB/s eta 0:00:00
# Collecting uvloop>=0.5.3 (from sanic<21.13,>=21.12->rasa)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2,>=0.22->rasa) (3.2.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite<0.4,>=0.3->rasa)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 55.8 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa) (2.0.2)
# Collecting aiohttp-retry>=2.8.3 (from twilio<8.3,>=6.26->rasa)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.18.3)
# Collecting requests-toolbelt (from webexteamssdk<1.7.0,>=1.1.1->rasa)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.3 MB/s eta 0:00:00
# Collecting pamqp==3.2.1 (from aiormq~=6.4.0->aio-pika<8.2.4,>=6.7.1->rasa)
#   Downloading pamqp-3.2.1-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0->rasa) (0.41.1)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.23->rasa)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3.1->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (1.15.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0->rasa) (0.2.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask==2022.10.2->rasa) (1.0.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3->rasa) (0.5.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (2.3.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3.1->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (2.21)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (3.2.2)
# Building wheels for collected packages: mattermostwrapper, randomname, docopt, fire
#   Building wheel for mattermostwrapper (setup.py) ... done
#   Created wheel for mattermostwrapper: filename=mattermostwrapper-2.2-py3-none-any.whl size=2448 sha256=2e3dab56edfa7a4bf5b4c6ecdc665c4a5dd0b3b4a6685e734434523cc170d80d
#   Stored in directory: /root/.cache/pip/wheels/b2/dc/02/e3239f0ea0a676085826846d32ef09b10915c0a33c817d2dbb
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.1.5-py3-none-any.whl size=58808 sha256=47acf79c767cefa92af75e162414f4c47d8763efa2f2811aa7cf363f9ab3bd08
#   Stored in directory: /root/.cache/pip/wheels/ee/df/c1/0bdf17c694217f49657ca36fd0239b9a243c34c27a70ff56ef
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=f97069e8e8d77923bde3f90ae1ed6b6f037b86ba1885afe1dc2c6b193069e6b4
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=de93f5549e407c9b84acc0013cdf3edc27301823fa636841c1b60368559967cd
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built mattermostwrapper randomname docopt fire
# Installing collected packages: sanic-routing, pytz, python-crfsuite, docopt, confluent-kafka, websockets, uvloop, urllib3, ujson, typing-utils, terminaltables, tensorflow-io-gcs-filesystem, tarsafe, structlog, SQLAlchemy, slack-sdk, sklearn-crfsuite, scipy, sanic-jwt, ruamel.yaml.clib, regex, redis, python-engineio, pyrsistent, pydantic, psycopg2-binary, protobuf, prompt-toolkit, portalocker, pamqp, packaging, networkx, multidict, magic-filter, joblib, jmespath, humanfriendly, httptools, fire, dnspython, colorhash, colorclass, bidict, Babel, attrs, apscheduler, aiofiles, tensorflow_hub, sentry-sdk, scikit-learn, sanic, ruamel.yaml, randomname, questionary, python-socketio, pymongo, matplotlib, jsonschema, dask, coloredlogs, botocore, structlog-sentry, sanic-cors, s3transfer, rocketchat_API, requests-toolbelt, pykwalify, mattermostwrapper, fbmessenger, CacheControl, aiormq, webexteamssdk, rasa-sdk, boto3, aiohttp-retry, aiogram, aio-pika, twilio, tensorflow-text, rasa
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3
#     Uninstalling pytz-2023.3:
#       Successfully uninstalled pytz-2023.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.33.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.33.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.33.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.19
#     Uninstalling SQLAlchemy-2.0.19:
#       Successfully uninstalled SQLAlchemy-2.0.19
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.6.3
#     Uninstalling regex-2023.6.3:
#       Successfully uninstalled regex-2023.6.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.39
#     Uninstalling prompt-toolkit-3.0.39:
#       Successfully uninstalled prompt-toolkit-3.0.39
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.0.4
#     Uninstalling multidict-6.0.4:
#       Successfully uninstalled multidict-6.0.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.12.1
#     Uninstalling Babel-2.12.1:
#       Successfully uninstalled Babel-2.12.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
#   Attempting uninstall: tensorflow_hub
#     Found existing installation: tensorflow-hub 0.14.0
#     Uninstalling tensorflow-hub-0.14.0:
#       Successfully uninstalled tensorflow-hub-0.14.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.0
#     Uninstalling jsonschema-4.19.0:
#       Successfully uninstalled jsonschema-4.19.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2023.8.0
#     Uninstalling dask-2023.8.0:
#       Successfully uninstalled dask-2023.8.0
#   Attempting uninstall: CacheControl
#     Found existing installation: CacheControl 0.13.1
#     Uninstalling CacheControl-0.13.1:
#       Successfully uninstalled CacheControl-0.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# distributed 2023.8.0 requires dask==2023.8.0, but you have dask 2022.10.2 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.
# plotnine 0.12.2 requires matplotlib>=3.6.0, but you have matplotlib 3.5.3 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 22.1.0 which is incompatible.
# statsmodels 0.14.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# xarray 2023.7.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# Successfully installed Babel-2.9.1 CacheControl-0.12.14 SQLAlchemy-1.4.49 aio-pika-8.2.3 aiofiles-23.2.1 aiogram-2.25.1 aiohttp-retry-2.8.3 aiormq-6.4.2 apscheduler-3.9.1.post1 attrs-22.1.0 bidict-0.22.1 boto3-1.28.25 botocore-1.31.25 colorclass-2.2.2 coloredlogs-15.0.1 colorhash-1.2.1 confluent-kafka-2.2.0 dask-2022.10.2 dnspython-2.4.2 docopt-0.6.2 fbmessenger-6.0.0 fire-0.5.0 httptools-0.6.0 humanfriendly-10.0 jmespath-1.0.1 joblib-1.2.0 jsonschema-4.17.3 magic-filter-1.0.11 matplotlib-3.5.3 mattermostwrapper-2.2 multidict-5.2.0 networkx-2.6.3 packaging-20.9 pamqp-3.2.1 portalocker-2.7.0 prompt-toolkit-3.0.28 protobuf-4.23.3 psycopg2-binary-2.9.7 pydantic-1.10.9 pykwalify-1.8.0 pymongo-4.3.3 pyrsistent-0.19.3 python-crfsuite-0.9.9 python-engineio-4.5.1 python-socketio-5.8.0 pytz-2022.7.1 questionary-1.10.0 randomname-0.1.5 rasa-3.6.4 rasa-sdk-3.6.1 redis-4.6.0 regex-2022.10.31 requests-toolbelt-1.0.0 rocketchat_API-1.30.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 s3transfer-0.6.1 sanic-21.12.2 sanic-cors-2.0.1 sanic-jwt-1.8.0 sanic-routing-0.7.2 scikit-learn-1.1.3 scipy-1.8.1 sentry-sdk-1.14.0 sklearn-crfsuite-0.3.6 slack-sdk-3.21.3 structlog-23.1.0 structlog-sentry-2.0.3 tarsafe-0.0.4 tensorflow-io-gcs-filesystem-0.32.0 tensorflow-text-2.12.0 tensorflow_hub-0.13.0 terminaltables-3.1.10 twilio-8.2.2 typing-utils-0.1.0 ujson-5.8.0 urllib3-1.26.16 uvloop-0.17.0 webexteamssdk-1.6.1 websockets-10.4

# %% [markdown]
# Update the IPython library. This ensures compatibility and resolves potential errors with Rasa. (It fixes an error you can get running !pip install rasa. Make sure you also press the reset rundown button)

# %%
# !pip install -U ipython
# Out:
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Collecting ipython
#   Downloading ipython-8.14.0-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.7/798.7 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython) (0.7.5)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 (from ipython)
#   Downloading prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (2.16.1)
# Collecting stack-data (from ipython)
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.10/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.6)
# Collecting executing>=1.2.0 (from stack-data->ipython)
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython)
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting pure-eval (from stack-data->ipython)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Installing collected packages: pure-eval, executing, prompt-toolkit, jedi, asttokens, stack-data, ipython
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.28
#     Uninstalling prompt-toolkit-3.0.28:
#       Successfully uninstalled prompt-toolkit-3.0.28
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.14.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.
# rasa 3.6.4 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.39 which is incompatible.
# rasa-sdk 3.6.1 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.39 which is incompatible.
# Successfully installed asttokens-2.2.1 executing-1.2.0 ipython-8.14.0 jedi-0.19.0 prompt-toolkit-3.0.39 pure-eval-0.2.2 stack-data-0.6.2

# %% [markdown]
# Initialize a new Rasa project in the current directory.
# The '--no-prompt' flag automates the process without asking for user input.

# %%
# !rasa init --no-prompt
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/core/tracker_store.py:1042: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# (0lqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B Rasa Open Source reports anonymous usage telemetry to help improve the product (0x(B
# (0x(B for all its users.                                                             (0x(B
# (0x(B                                                                                (0x(B
# (0x(B If you'd like to opt-out, you can use `rasa telemetry disable`.                (0x(B
# (0x(B To learn more, check out https://rasa.com/docs/rasa/telemetry/telemetry.       (0x(B
# (0mqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqj(B
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.logging')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.iam')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel.yaml')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Welcome to Rasa! 🤖
#
# To get started quickly, an initial project will be created.
# If you need some help, check out the documentation at https://rasa.com/docs/rasa.
#
# 2023-08-14 13:22:18 INFO     root  - creating tests
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/tests/test_stories.yml -> ./tests
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/domain.yml -> .
# 2023-08-14 13:22:18 INFO     root  - creating data
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/data/nlu.yml -> ./data
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/data/rules.yml -> ./data
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/data/stories.yml -> ./data
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/credentials.yml -> .
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/config.yml -> .
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/endpoints.yml -> .
# 2023-08-14 13:22:18 INFO     root  - creating actions
# 2023-08-14 13:22:18 INFO     root  - creating actions/__pycache__
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/actions/__pycache__/__init__.cpython-310.pyc -> ./actions/__pycache__
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/actions/__pycache__/actions.cpython-310.pyc -> ./actions/__pycache__
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/actions/__init__.py -> ./actions
# 2023-08-14 13:22:18 INFO     root  - copying /usr/local/lib/python3.10/dist-packages/rasa/cli/initial_project/actions/actions.py -> ./actions
# Created project directory at '/content'.
# Finished creating project structure.
# Training an initial model...
# 2023-08-14 13:22:22 INFO     numexpr.utils  - NumExpr defaulting to 2 threads.
# The configuration for policies and pipeline was chosen automatically. It was written into the config file at 'config.yml'.
# 2023-08-14 13:22:26 INFO     rasa.engine.training.hooks  - Starting to train component 'RegexFeaturizer'.
# 2023-08-14 13:22:26 INFO     rasa.engine.training.hooks  - Finished training component 'RegexFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Starting to train component 'LexicalSyntacticFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Finished training component 'LexicalSyntacticFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Starting to train component 'CountVectorsFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.nlu.featurizers.sparse_featurizer.count_vectors_featurizer  - 80 vocabulary items were created for text attribute.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Finished training component 'CountVectorsFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Starting to train component 'CountVectorsFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.nlu.featurizers.sparse_featurizer.count_vectors_featurizer  - 697 vocabulary items were created for text attribute.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Finished training component 'CountVectorsFeaturizer'.
# 2023-08-14 13:22:27 INFO     rasa.engine.training.hooks  - Starting to train component 'DIETClassifier'.
# Epochs: 100% 100/100 [00:49<00:00,  2.03it/s, t_loss=1.14, i_acc=1]
# 2023-08-14 13:23:24 INFO     rasa.engine.training.hooks  - Finished training component 'DIETClassifier'.
# 2023-08-14 13:23:24 INFO     rasa.engine.training.hooks  - Starting to train component 'EntitySynonymMapper'.
# 2023-08-14 13:23:24 INFO     rasa.engine.training.hooks  - Finished training component 'EntitySynonymMapper'.
# 2023-08-14 13:23:24 INFO     rasa.engine.training.hooks  - Starting to train component 'ResponseSelector'.
# 2023-08-14 13:23:24 INFO     rasa.nlu.selectors.response_selector  - Retrieval intent parameter was left to its default value. This response selector will be trained on training examples combining all retrieval intents.
# 2023-08-14 13:23:24 INFO     rasa.engine.training.hooks  - Finished training component 'ResponseSelector'.
# Processed story blocks: 100% 3/3 [00:00<00:00, 1401.37it/s, # trackers=1]
# Processed story blocks: 100% 3/3 [00:00<00:00, 614.40it/s, # trackers=3]
# Processed story blocks: 100% 3/3 [00:00<00:00, 155.83it/s, # trackers=12]
# Processed story blocks: 100% 3/3 [00:00<00:00, 37.00it/s, # trackers=39]
# Processed rules: 100% 2/2 [00:00<00:00, 2524.41it/s, # trackers=1]
# 2023-08-14 13:23:25 INFO     rasa.engine.training.hooks  - Starting to train component 'MemoizationPolicy'.
# Processed trackers: 100% 3/3 [00:00<00:00, 1417.47it/s, # action=12]
# Processed actions: 12it [00:00, 5372.72it/s, # examples=12]
# 2023-08-14 13:23:25 INFO     rasa.engine.training.hooks  - Finished training component 'MemoizationPolicy'.
# 2023-08-14 13:23:25 INFO     rasa.engine.training.hooks  - Starting to train component 'RulePolicy'.
# Processed trackers: 100% 2/2 [00:00<00:00, 1035.63it/s, # action=5]
# Processed actions: 5it [00:00, 9528.18it/s, # examples=4]
# Processed trackers: 100% 3/3 [00:00<00:00, 1597.22it/s, # action=12]
# Processed trackers: 100% 2/2 [00:00<00:00, 977.92it/s]
# Processed trackers: 100% 5/5 [00:00<00:00, 746.48it/s]
# 2023-08-14 13:23:26 INFO     rasa.engine.training.hooks  - Finished training component 'RulePolicy'.
# 2023-08-14 13:23:26 INFO     rasa.engine.training.hooks  - Starting to train component 'TEDPolicy'.
# Processed trackers: 100% 120/120 [00:00<00:00, 2313.40it/s, # action=30]
# Epochs: 100% 100/100 [00:25<00:00,  3.88it/s, t_loss=1.97, loss=1.81, acc=1]
# 2023-08-14 13:23:52 INFO     rasa.engine.training.hooks  - Finished training component 'TEDPolicy'.
# 2023-08-14 13:23:52 INFO     rasa.engine.training.hooks  - Starting to train component 'UnexpecTEDIntentPolicy'.
# 2023-08-14 13:23:52 WARNING  rasa.shared.utils.common  - The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Processed trackers: 100% 120/120 [00:00<00:00, 3596.20it/s, # intent=12]
# Epochs: 100% 100/100 [00:23<00:00,  4.19it/s, t_loss=0.139, loss=0.022, acc=0.992]
# 2023-08-14 13:24:25 INFO     rasa.engine.training.hooks  - Finished training component 'UnexpecTEDIntentPolicy'.
# Your Rasa model is trained and saved at 'models/20230814-132226-narrow-rhea.tar.gz'.
# If you want to speak to the assistant, run 'rasa shell' at any time inside the project directory.

# %% [markdown]
# # Define NLU, Stories and domain
#
# In a nutshell,
# - The nlu provides the training data for understanding user messages.
# - the stories train the bot on the conversation flow.
# - the domain dictates what actions, responses, and data storage mechanisms are available during those conversations.

# %% [markdown]
# **NLU**
#
# Define the training data for the chatbot's NLU.
# This data includes various intents (like greet, goodbye, mood_great) and their respective example phrases.
# Writing this data to 'data/nlu.yml' provides Rasa with examples to train the model on how to understand user inputs.

# %%
nlu_data_yml = """
version: "3.1"

nlu:
- intent: greet
  examples: |
    - hey
    - hello
    - hi
    - hello there
    - good morning
    - good evening
    - moin
    - hey there
    - let's go
    - hey dude
    - goodmorning
    - goodevening
    - good afternoon

- intent: goodbye
  examples: |
    - cu
    - good by
    - cee you later
    - good night
    - bye
    - goodbye
    - have a nice day
    - see you around
    - bye bye
    - see you later

- intent: affirm
  examples: |
    - yes
    - y
    - indeed
    - of course
    - that sounds good
    - correct

- intent: deny
  examples: |
    - no
    - n
    - never
    - I don't think so
    - don't like that
    - no way
    - not really

- intent: mood_great
  examples: |
    - perfect
    - great
    - amazing
    - feeling like a king
    - wonderful
    - I am feeling very good
    - I am great
    - I am amazing
    - I am going to save the world
    - super stoked
    - extremely good
    - so so perfect
    - so good
    - so perfect

- intent: mood_unhappy
  examples: |
    - my day was horrible
    - I am sad
    - I don't feel very well
    - I am disappointed
    - super sad
    - I'm so sad
    - sad
    - very sad
    - unhappy
    - not good
    - not very good
    - extremly sad
    - so saad
    - so sad

- intent: bot_challenge
  examples: |
    - are you a bot?
    - are you a human?
    - am I talking to a bot?
    - am I talking to a human?
"""

with open('data/nlu.yml', 'w') as f:
    f.write(nlu_data_yml)

# %% [markdown]
# **Stories**
#
# Define the training stories for the chatbot.
# Stories represent sequences of user messages and bot responses used to train the dialogue management model.
# They guide the bot on how to respond based on historical conversation patterns.

# %%
stories_data = """
version: "3.1"

stories:

- story: happy path
  steps:
  - intent: greet
  - action: utter_greet
  - intent: mood_great
  - action: utter_happy

- story: sad path 1
  steps:
  - intent: greet
  - action: utter_greet
  - intent: mood_unhappy
  - action: utter_cheer_up
  - action: utter_did_that_help
  - intent: affirm
  - action: utter_happy

- story: sad path 2
  steps:
  - intent: greet
  - action: utter_greet
  - intent: mood_unhappy
  - action: utter_cheer_up
  - action: utter_did_that_help
  - intent: deny
  - action: utter_goodbye
"""

with open('data/stories.yml', 'w') as f:
    f.write(stories_data)

# %% [markdown]
# **Domain**
#
# The 'domain.yml' serves as a blueprint for our chatbot's capabilities:
#
# 1. Intents: Enumerates the kinds of user input the bot can recognize.
# 2. Responses: Specifies how the bot should reply to each recognized intent.
# 3. Actions: Lists the potential actions the bot can take, encompassing both utterances and any custom functionalities.
# 4. (Not used here, but i thought i'd mention it anyway) Entities and Slots: Highlight the specific pieces of information the bot can recognize and retain during a conversation.
#
# By detailing these elements in the domain, we're furnishing the bot with its "vocabulary" of actions and responses it can use in ongoing interactions.

# %%
domain_data = """
intents:
  - greet
  - goodbye
  - mood_great
  - mood_unhappy
  - affirm
  - deny
  - bot_challenge

responses:
  utter_greet:
  - text: "Hello! How can I help you?"

  utter_goodbye:
  - text: "Goodbye!"

  utter_happy:
  - text: "I'm glad you're feeling great!"

  utter_cheer_up:
  - text: "Oh no! I hope I can make your day better."

  utter_did_that_help:
  - text: "Did that help?"

  utter_iamabot:
  - text: "I am a bot!"

  utter_default:
  - text: "Lol, I don't know."

actions:
- utter_greet
- utter_goodbye
- utter_happy
- utter_cheer_up
- utter_did_that_help
- utter_iamabot
"""

with open('domain.yml', 'w') as f:
    f.write(domain_data)

# %% [markdown]
# **Bot config**
# - "pipeline": Defines how the bot understands what you say.
# - The bot uses some fancy tools like DIET to guess what you're talking about.
# - "policies": Decides how our bot responds.
# - Main reason i defined this instead of leaving it default? -> for the FallbackPolicy. This gets used to make the bot say:"Lol, I don't know." when its unsure (nlu_threshold: 0.3 means any response with a confidence below 30% will result in the fallback response) on how to respond.

# %%
config_data = """
language: en
pipeline:
  - name: WhitespaceTokenizer
  - name: RegexFeaturizer
  - name: LexicalSyntacticFeaturizer
  - name: CountVectorsFeaturizer
  - name: CountVectorsFeaturizer
    analyzer: "char_wb"
    min_ngram: 1
    max_ngram: 4
  - name: DIETClassifier
    epochs: 100
    constrain_similarities: true
    model_confidence: "softmax"
  - name: FallbackClassifier
    confidence_threshold: 1
  - name: EntitySynonymMapper
  - name: ResponseSelector
    epochs: 100
    constrain_similarities: true
policies:
  - name: MemoizationPolicy
  - name: TEDPolicy
    max_history: 5
    epochs: 100
    constrain_similarities: true
  - name: RulePolicy
"""

with open('config.yml', 'w') as f:
    f.write(config_data)

# %% [markdown]
# **Training the model**
#
# Using the 'rasa train' command, we compile all the data we've provided (NLU, stories, and domain) into a machine learning model. This model will be used by our chatbot to predict the next best action based on user input.
#
# Essentially, this command is where the magic happens –> turning our defined conversational patterns and intents into a functioning chatbot brain.

# %%
# !rasa train
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/core/tracker_store.py:1042: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.logging')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.iam')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel.yaml')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# 2023-08-14 14:09:09 INFO     rasa.cli.train  - Started validating domain and training data...
# 2023-08-14 14:09:12 INFO     numexpr.utils  - NumExpr defaulting to 2 threads.
# 2023-08-14 14:09:13 INFO     rasa.shared.utils.validation  - The 'version' key is missing in the training data file /content/domain.yml. Rasa Open Source will read the file as a version '3.1' file. See https://rasa.com/docs/rasa/training-data-format.
# 2023-08-14 14:09:13 INFO     rasa.shared.utils.validation  - The 'version' key is missing in the training data file /content/domain.yml. Rasa Open Source will read the file as a version '3.1' file. See https://rasa.com/docs/rasa/training-data-format.
# 2023-08-14 14:09:14 INFO     rasa.validator  - Validating intents...
# 2023-08-14 14:09:14 INFO     rasa.validator  - Validating uniqueness of intents and stories...
# 2023-08-14 14:09:14 INFO     rasa.validator  - Validating utterances...
# 2023-08-14 14:09:14 INFO     rasa.validator  - Story structure validation...
# Processed story blocks: 100% 3/3 [00:00<00:00, 1950.54it/s, # trackers=1]
# 2023-08-14 14:09:14 INFO     rasa.core.training.story_conflict  - Considering all preceding turns for conflict analysis.
# 2023-08-14 14:09:14 INFO     rasa.validator  - No story structure conflicts found.
# 2023-08-14 14:09:14 INFO     rasa.shared.utils.validation  - The 'version' key is missing in the training data file /content/domain.yml. Rasa Open Source will read the file as a version '3.1' file. See https://rasa.com/docs/rasa/training-data-format.
# 2023-08-14 14:09:15 INFO     rasa.shared.utils.validation  - The 'version' key is missing in the training data file /content/domain.yml. Rasa Open Source will read the file as a version '3.1' file. See https://rasa.com/docs/rasa/training-data-format.
# /usr/local/lib/python3.10/dist-packages/rasa/engine/recipes/recipe.py:35: FutureWarning: From Rasa Open Source 4.0.0 onwards it will be required to specify a recipe in your model configuration. Defaulting to recipe 'default.v1'.
#   rasa.shared.utils.io.raise_deprecation_warning(
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Starting to train component 'RegexFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Finished training component 'RegexFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Starting to train component 'LexicalSyntacticFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Finished training component 'LexicalSyntacticFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Starting to train component 'CountVectorsFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.nlu.featurizers.sparse_featurizer.count_vectors_featurizer  - 80 vocabulary items were created for text attribute.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Finished training component 'CountVectorsFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Starting to train component 'CountVectorsFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.nlu.featurizers.sparse_featurizer.count_vectors_featurizer  - 697 vocabulary items were created for text attribute.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Finished training component 'CountVectorsFeaturizer'.
# 2023-08-14 14:09:16 INFO     rasa.engine.training.hooks  - Starting to train component 'DIETClassifier'.
# Epochs: 100% 100/100 [00:51<00:00,  1.96it/s, t_loss=1.09, i_acc=1]
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Finished training component 'DIETClassifier'.
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Starting to train component 'EntitySynonymMapper'.
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Finished training component 'EntitySynonymMapper'.
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Starting to train component 'ResponseSelector'.
# 2023-08-14 14:10:14 INFO     rasa.nlu.selectors.response_selector  - Retrieval intent parameter was left to its default value. This response selector will be trained on training examples combining all retrieval intents.
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Finished training component 'ResponseSelector'.
# Processed story blocks: 100% 3/3 [00:00<00:00, 2157.93it/s, # trackers=1]
# Processed story blocks: 100% 3/3 [00:00<00:00, 1121.97it/s, # trackers=3]
# Processed story blocks: 100% 3/3 [00:00<00:00, 260.78it/s, # trackers=12]
# Processed story blocks: 100% 3/3 [00:00<00:00, 70.04it/s, # trackers=39]
# Processed rules: 100% 3/3 [00:00<00:00, 3695.42it/s, # trackers=1]
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Starting to train component 'MemoizationPolicy'.
# Processed trackers: 100% 3/3 [00:00<00:00, 1755.18it/s, # action=12]
# Processed actions: 12it [00:00, 6945.17it/s, # examples=12]
# 2023-08-14 14:10:14 INFO     rasa.engine.training.hooks  - Finished training component 'MemoizationPolicy'.
# 2023-08-14 14:10:15 INFO     rasa.engine.training.hooks  - Starting to train component 'RulePolicy'.
# Processed trackers: 100% 3/3 [00:00<00:00, 1659.80it/s, # action=7]
# Processed actions: 7it [00:00, 11482.26it/s, # examples=6]
# Processed trackers: 100% 3/3 [00:00<00:00, 2072.63it/s, # action=12]
# Processed trackers: 100% 3/3 [00:00<00:00, 1646.98it/s]
# Processed trackers: 100% 6/6 [00:00<00:00, 1372.63it/s]
# 2023-08-14 14:10:15 INFO     rasa.engine.training.hooks  - Finished training component 'RulePolicy'.
# 2023-08-14 14:10:15 INFO     rasa.engine.training.hooks  - Starting to train component 'TEDPolicy'.
# Processed trackers: 100% 120/120 [00:00<00:00, 2284.80it/s, # action=30]
# Epochs: 100% 100/100 [00:27<00:00,  3.58it/s, t_loss=1.86, loss=1.7, acc=1]
# 2023-08-14 14:10:53 INFO     rasa.engine.training.hooks  - Finished training component 'TEDPolicy'.
# Your Rasa model is trained and saved at 'models/20230814-140915-humane-jig.tar.gz'.

# %% [markdown]
# Running '!rasa shell' kicks off an interactive chat with the bot here on colab. This is a quick and easy way to test the bot, without having to do a bunch of additional setup or downloads.

# %%
# !rasa shell
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/core/tracker_store.py:1042: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.logging')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.iam')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel.yaml')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# 2023-08-14 14:11:14 INFO     numexpr.utils  - NumExpr defaulting to 2 threads.
# /usr/local/lib/python3.10/dist-packages/sanic_cors/extension.py:39: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   SANIC_VERSION = LooseVersion(sanic_version)
# 2023-08-14 14:11:17 INFO     root  - Connecting to channel 'cmdline' which was specified by the '--connector' argument. Any other channels will be ignored. To connect to all given channels, omit the '--connector' argument.
# 2023-08-14 14:11:17 INFO     root  - Starting Rasa server on http://0.0.0.0:5005
# 2023-08-14 14:11:17 INFO     rasa.core.processor  - Loading model models/20230814-140915-humane-jig.tar.gz...
# 2023-08-14 14:11:57 INFO     root  - Rasa server is up and running.
# Bot loaded. Type a message and press enter (use '/stop' to exit):
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Oh no! I hope I can make your day better.
# Did that help?
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Goodbye!
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Hello! How can I help you?
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# I am a bot!
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# I'm glad you're feeling great!
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Oh no! I hope I can make your day better.
# Did that help?
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Oh no! I hope I can make your day better.
# Did that help?
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# I'm glad you're feeling great!
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Goodbye!
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# 2023-08-14 14:13:22 INFO     root  - Killing Sanic server now.
